# %%
import numpy as np
import pandas as pd

# %%
df_orders = pd.read_excel('Sample - Superstore.xls', sheet_name=0)
df_people = pd.read_excel('Sample - Superstore.xls', sheet_name=1)
df_returns = pd.read_excel('Sample - Superstore.xls', sheet_name=2)

# %%
df_orders.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 1       2  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 2       3  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045
# 3       4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
# 4       5  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df_people.head()
# Out:
#     Regional Manager   Region
# 0    Sadie Pawthorne     West
# 1        Chuck Magee     East
# 2  Roxanne Rodriguez  Central
# 3        Fred Suzuki    South

# %%
df_returns.head()
# Out:
#   Returned        Order ID
# 0      Yes  CA-2018-100762
# 1      Yes  CA-2018-100762
# 2      Yes  CA-2018-100762
# 3      Yes  CA-2018-100762
# 4      Yes  CA-2018-100867

# %%
df_returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Returned  800 non-null    object
#  1   Order ID  800 non-null    object
# dtypes: object(2)
# memory usage: 12.6+ KB

# %%
df_returns.describe()
# Out:
#        Returned        Order ID
# count       800             800
# unique        1             296
# top         Yes  CA-2021-100111
# freq        800              14

# %%
print('Duplicate entries: ', df_returns.duplicated().sum())
# Out:
# Duplicate entries:  504

# %%
df_returns.columns
# Out:
# Index(['Returned', 'Order ID'], dtype='object')

# %%
df_returns['Returned'].unique()
# Out:
# array(['Yes'], dtype=object)

# %%
df_returns['Order ID'].unique()
# Out:
# array(['CA-2018-100762', 'CA-2018-100867', 'CA-2018-102652',
#        'CA-2018-103373', 'CA-2018-103744', 'CA-2018-103940',
#        'CA-2018-104829', 'CA-2018-105270', 'CA-2018-108609',
#        'CA-2018-108861', 'CA-2018-109918', 'CA-2018-110786',
#        'CA-2018-111871', 'CA-2018-116785', 'CA-2018-123225',
#        'CA-2018-123253', 'CA-2018-123498', 'CA-2018-124688',
#        'CA-2018-126361', 'CA-2018-126403', 'CA-2018-126522',
#        'CA-2018-127012', 'CA-2018-127131', 'CA-2018-133690',
#        'CA-2018-134726', 'CA-2018-135657', 'CA-2018-135699',
#        'CA-2018-140816', 'CA-2018-141726', 'CA-2018-142769',
#        'CA-2018-143336', 'CA-2018-143840', 'CA-2018-148614',
#        'CA-2018-148950', 'CA-2018-151162', 'CA-2018-152345',
#        'CA-2018-153150', 'CA-2018-156349', 'CA-2018-157924',
#        'CA-2018-159338', 'CA-2018-160766', 'CA-2018-160773',
#        'CA-2018-164721', 'CA-2018-164861', 'CA-2018-166744',
# ...

# %%
print('Unique order IDs: ', len(df_returns['Order ID'].unique()))
# Out:
# Unique order IDs:  296

# %%
df_returns.isna().sum()
# Out:
# Returned    0
# Order ID    0
# dtype: int64

# %%
df_returns.groupby('Order ID').agg({'Returned' : 'count'})
# Out:
#                 Returned
# Order ID
# CA-2018-100762         4
# CA-2018-100867         1
# CA-2018-102652         4
# CA-2018-103373         1
# CA-2018-103744         2
# ...                  ...
# US-2021-136679         2
# US-2021-147886         7
# US-2021-147998         1
# US-2021-151127         1
# US-2021-155999         2
#
# [296 rows x 1 columns]

# %%
df_returns_cleaned = df_returns.copy()
df_returns_cleaned['Returned Count'] = df_returns_cleaned.groupby('Order ID')['Returned'].transform('count')
df_returns_cleaned.head()
# Out:
#   Returned        Order ID  Returned Count
# 0      Yes  CA-2018-100762               4
# 1      Yes  CA-2018-100762               4
# 2      Yes  CA-2018-100762               4
# 3      Yes  CA-2018-100762               4
# 4      Yes  CA-2018-100867               1

# %%
print('Duplicate entries: ', df_returns_cleaned.duplicated().sum())
# Out:
# Duplicate entries:  504

# %%
df_returns_cleaned = df_returns_cleaned.drop_duplicates()
df_returns_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 296 entries, 0 to 798
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Returned        296 non-null    object
#  1   Order ID        296 non-null    object
#  2   Returned Count  296 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 9.2+ KB

# %%
df_returns_cleaned = df_returns_cleaned.drop('Returned', axis=1)
df_returns_cleaned.head()
# Out:
#           Order ID  Returned Count
# 0   CA-2018-100762               4
# 4   CA-2018-100867               1
# 5   CA-2018-102652               4
# 9   CA-2018-103373               1
# 10  CA-2018-103744               2

# %%
df_returns_cleaned = df_returns_cleaned.reset_index(drop=True)
df_returns_cleaned.head()
# Out:
#          Order ID  Returned Count
# 0  CA-2018-100762               4
# 1  CA-2018-100867               1
# 2  CA-2018-102652               4
# 3  CA-2018-103373               1
# 4  CA-2018-103744               2

# %%
df_people.head()
# Out:
#     Regional Manager   Region
# 0    Sadie Pawthorne     West
# 1        Chuck Magee     East
# 2  Roxanne Rodriguez  Central
# 3        Fred Suzuki    South

# %%
df_people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Regional Manager  4 non-null      object
#  1   Region            4 non-null      object
# dtypes: object(2)
# memory usage: 196.0+ bytes

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
# ...

# %%
df_orders.isna().sum()
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64

# %%
print('No. of Duplicate Rows: ', df_orders.duplicated().sum())
# Out:
# No. of Duplicate Rows:  0

# %%
df_orders.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 1       2  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 2       3  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045
# 3       4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
# 4       5  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df_orders_1 = df_orders.copy()
df_orders_1 = df_orders_1.drop('Row ID', axis=1)
df_orders_1 = df_orders_1.reset_index(drop=True)
df_orders_1.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 1  CA-2020-152156 2020-11-08 2020-11-11    Second Class    CG-12520
# 2  CA-2020-138688 2020-06-12 2020-06-16    Second Class    DV-13045
# 3  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
# 4  US-2019-108966 2019-10-11 2019-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
print('No. of Duplicate Rows: ', df_orders_1.duplicated().sum())
# Out:
# No. of Duplicate Rows:  1

# %%
df_orders_1 = df_orders_1.drop_duplicates()
df_orders_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9993 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        9993 non-null   object
#  1   Order Date      9993 non-null   datetime64[ns]
#  2   Ship Date       9993 non-null   datetime64[ns]
#  3   Ship Mode       9993 non-null   object
#  4   Customer ID     9993 non-null   object
#  5   Customer Name   9993 non-null   object
#  6   Segment         9993 non-null   object
#  7   Country/Region  9993 non-null   object
#  8   City            9993 non-null   object
#  9   State           9993 non-null   object
#  10  Postal Code     9982 non-null   float64
#  11  Region          9993 non-null   object
#  12  Product ID      9993 non-null   object
#  13  Category        9993 non-null   object
#  14  Sub-Category    9993 non-null   object
#  15  Product Name    9993 non-null   object
#  16  Sales           9993 non-null   float64
# ...

# %%
df_orders_1.isna().sum()
# Out:
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64

# %%
#display all rows with postal code is null
df_orders_1[df_orders_1['Postal Code'].isnull()]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2234  CA-2021-104066 2021-12-05 2021-12-10  Standard Class    QJ-19255
# 5274  CA-2019-162887 2019-11-07 2019-11-09    Second Class    SV-20785
# 8798  US-2020-150140 2020-04-06 2020-04-10  Standard Class    VM-21685
# 9146  US-2020-165505 2020-01-23 2020-01-27  Standard Class    CB-12535
# 9147  US-2020-165505 2020-01-23 2020-01-27  Standard Class    CB-12535
# 9148  US-2020-165505 2020-01-23 2020-01-27  Standard Class    CB-12535
# 9386  US-2021-127292 2021-01-19 2021-01-23  Standard Class    RM-19375
# 9387  US-2021-127292 2021-01-19 2021-01-23  Standard Class    RM-19375
# 9388  US-2021-127292 2021-01-19 2021-01-23  Standard Class    RM-19375
# 9389  US-2021-127292 2021-01-19 2021-01-23  Standard Class    RM-19375
# 9741  CA-2019-117086 2019-11-08 2019-11-12  Standard Class    QJ-19255
#
#          Customer Name      Segment Country/Region        City    State  \
# ...

# %%
df_orders_1[['City', 'State', 'Postal Code']].sort_values(by='City', ascending=False).head(50)
#observation is that 1 city is associated with 1 postal code
# Out:
#             City           State  Postal Code
# 7279        Yuma         Arizona      85364.0
# 7281        Yuma         Arizona      85364.0
# 4822        Yuma         Arizona      85364.0
# 8087        Yuma         Arizona      85364.0
# 3347     Yucaipa      California      92399.0
# 2145        York    Pennsylvania      17403.0
# 2146        York    Pennsylvania      17403.0
# 2147        York    Pennsylvania      17403.0
# 8475        York    Pennsylvania      17403.0
# 8474        York    Pennsylvania      17403.0
# 8500     Yonkers        New York      10701.0
# 3862     Yonkers        New York      10701.0
# 1082     Yonkers        New York      10701.0
# 3699     Yonkers        New York      10701.0
# 1084     Yonkers        New York      10701.0
# 1085     Yonkers        New York      10701.0
# 5268     Yonkers        New York      10701.0
# 5296     Yonkers        New York      10701.0
# 5297     Yonkers        New York      10701.0
# ...

# %%
df_orders_temp = df_orders_1[df_orders_1['City'].isin(['Burlington'])]
df_orders_temp[df_orders_temp['State'].isin(['Vermont'])]
#observation: in the current data we are not able to find information to impute missing Postal code
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2234  CA-2021-104066 2021-12-05 2021-12-10  Standard Class    QJ-19255
# 5274  CA-2019-162887 2019-11-07 2019-11-09    Second Class    SV-20785
# 8798  US-2020-150140 2020-04-06 2020-04-10  Standard Class    VM-21685
# 9146  US-2020-165505 2020-01-23 2020-01-27  Standard Class    CB-12535
# 9147  US-2020-165505 2020-01-23 2020-01-27  Standard Class    CB-12535
# 9148  US-2020-165505 2020-01-23 2020-01-27  Standard Class    CB-12535
# 9386  US-2021-127292 2021-01-19 2021-01-23  Standard Class    RM-19375
# 9387  US-2021-127292 2021-01-19 2021-01-23  Standard Class    RM-19375
# 9388  US-2021-127292 2021-01-19 2021-01-23  Standard Class    RM-19375
# 9389  US-2021-127292 2021-01-19 2021-01-23  Standard Class    RM-19375
# 9741  CA-2019-117086 2019-11-08 2019-11-12  Standard Class    QJ-19255
#
#          Customer Name      Segment Country/Region        City    State  \
# ...

# %%
df_orders_1['Postal Code'] = df_orders_1['Postal Code'].fillna(0)
df_orders_temp = df_orders_1[df_orders_1['City'].isin(['Burlington'])]
df_orders_temp[df_orders_temp['State'].isin(['Vermont'])]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2234  CA-2021-104066 2021-12-05 2021-12-10  Standard Class    QJ-19255
# 5274  CA-2019-162887 2019-11-07 2019-11-09    Second Class    SV-20785
# 8798  US-2020-150140 2020-04-06 2020-04-10  Standard Class    VM-21685
# 9146  US-2020-165505 2020-01-23 2020-01-27  Standard Class    CB-12535
# 9147  US-2020-165505 2020-01-23 2020-01-27  Standard Class    CB-12535
# 9148  US-2020-165505 2020-01-23 2020-01-27  Standard Class    CB-12535
# 9386  US-2021-127292 2021-01-19 2021-01-23  Standard Class    RM-19375
# 9387  US-2021-127292 2021-01-19 2021-01-23  Standard Class    RM-19375
# 9388  US-2021-127292 2021-01-19 2021-01-23  Standard Class    RM-19375
# 9389  US-2021-127292 2021-01-19 2021-01-23  Standard Class    RM-19375
# 9741  CA-2019-117086 2019-11-08 2019-11-12  Standard Class    QJ-19255
#
#          Customer Name      Segment Country/Region        City    State  \
# ...

# %%
df_orders_1.describe()
# Out:
#                           Order Date                      Ship Date  \
# count                           9993                           9993
# mean   2020-04-30 01:53:24.443110144  2020-05-04 00:53:19.039327488
# min              2018-01-03 00:00:00            2018-01-07 00:00:00
# 25%              2019-05-23 00:00:00            2019-05-27 00:00:00
# 50%              2020-06-26 00:00:00            2020-06-29 00:00:00
# 75%              2021-05-14 00:00:00            2021-05-18 00:00:00
# max              2021-12-30 00:00:00            2022-01-05 00:00:00
# std                              NaN                            NaN
#
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9993.000000   9993.000000  9993.000000  9993.000000  9993.000000
# mean   55185.623436    229.852846     3.789753     0.156188    28.660971
# min        0.000000      0.444000     1.000000     0.000000 -6599.978000
# ...

# %%
df_orders_1[df_orders_1['Order Date'] > df_orders_1['Ship Date']]
# Out:
# Empty DataFrame
# Columns: [Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country/Region, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []

# %%
df_orders_1[df_orders_1['Order Date'] < df_orders_1['Ship Date']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9474 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        9474 non-null   object
#  1   Order Date      9474 non-null   datetime64[ns]
#  2   Ship Date       9474 non-null   datetime64[ns]
#  3   Ship Mode       9474 non-null   object
#  4   Customer ID     9474 non-null   object
#  5   Customer Name   9474 non-null   object
#  6   Segment         9474 non-null   object
#  7   Country/Region  9474 non-null   object
#  8   City            9474 non-null   object
#  9   State           9474 non-null   object
#  10  Postal Code     9474 non-null   float64
#  11  Region          9474 non-null   object
#  12  Product ID      9474 non-null   object
#  13  Category        9474 non-null   object
#  14  Sub-Category    9474 non-null   object
#  15  Product Name    9474 non-null   object
#  16  Sales           9474 non-null   float64
# ...

# %%
#unique values in every column
for col in df_orders_1.columns:
    print(col, ':', df_orders_1[col].unique())
# Out:
# Order ID : ['CA-2020-152156' 'CA-2020-138688' 'US-2019-108966' ... 'CA-2018-110422'
#  'CA-2021-121258' 'CA-2021-119914']
# Order Date : <DatetimeArray>
# ['2020-11-08 00:00:00', '2020-06-12 00:00:00', '2019-10-11 00:00:00',
#  '2018-06-09 00:00:00', '2021-04-15 00:00:00', '2020-12-05 00:00:00',
#  '2019-11-22 00:00:00', '2018-11-11 00:00:00', '2018-05-13 00:00:00',
#  '2018-08-27 00:00:00',
#  ...
#  '2020-10-11 00:00:00', '2018-06-18 00:00:00', '2021-02-28 00:00:00',
#  '2019-05-09 00:00:00', '2018-11-06 00:00:00', '2019-12-29 00:00:00',
#  '2018-04-03 00:00:00', '2020-06-03 00:00:00', '2019-04-12 00:00:00',
#  '2018-01-21 00:00:00']
# Length: 1236, dtype: datetime64[ns]
# Ship Date : <DatetimeArray>
# ['2020-11-11 00:00:00', '2020-06-16 00:00:00', '2019-10-18 00:00:00',
#  '2018-06-14 00:00:00', '2021-04-20 00:00:00', '2020-12-10 00:00:00',
#  '2019-11-26 00:00:00', '2018-11-18 00:00:00', '2018-05-15 00:00:00',
#  '2018-09-01 00:00:00',
#  ...
# ...
